# %% [markdown]
# # Fraud Detection in Online Transactions
#
# Dataset: IEEE-CIS Fraud Detection (Kaggle)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load dataset (make sure file is in data/raw/)
data = pd.read_csv('data/raw/student_performance.csv', sep=';')

# Preview data
data.head()
# Out:
#   student_id,weekly_self_study_hours,attendance_percentage,class_participation,total_score,grade
# 0                             1,18.5,95.6,3.8,97.9,A
# 1                             2,14.0,80.0,2.5,83.9,B
# 2                            3,19.5,86.3,5.3,100.0,A
# 3                            4,25.7,70.2,7.0,100.0,A
# 4                             5,13.4,81.9,6.9,92.0,A

# %%
# Shape of dataset
print("Shape:", data.shape)

# Data types and info
data.info()

# Statistical summary
data.describe()
# Out:
# Shape: (1000000, 1)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 1 columns):
#  #   Column                                                                                          Non-Null Count    Dtype
# ---  ------                                                                                          --------------    -----
#  0   student_id,weekly_self_study_hours,attendance_percentage,class_participation,total_score,grade  1000000 non-null  object
# dtypes: object(1)
# memory usage: 7.6+ MB
#        student_id,weekly_self_study_hours,attendance_percentage,class_participation,total_score,grade
# count                                             1000000
# unique                                            1000000
# top                                1,18.5,95.6,3.8,97.9,A
# freq                                                    1

# %%
# Check for missing values
print("Missing values:\n", data.isnull().sum())
# Out:
# Missing values:
#  student_id,weekly_self_study_hours,attendance_percentage,class_participation,total_score,grade    0
# dtype: int64

# %%
for col in data.select_dtypes(include='object').columns:
    data[col] = data[col].astype('category').cat.codes

data.head()
# Out:
#    student_id,weekly_self_study_hours,attendance_percentage,class_participation,total_score,grade
# 0                                                  0
# 1                                             111112
# 2                                             222223
# 3                                             333334
# 4                                             444445

# %%
import os
os.makedirs('data/processed', exist_ok=True)

# Save cleaned dataset
data.to_csv('data/processed/cleaned_student_data.csv', index=False)

print("Processed data saved!")
# Out:
# Processed data saved!

# %%
import matplotlib.pyplot as plt

plt.figure()

plt.title('Final Grade Distribution')
plt.xlabel('Final Grade (G3)')
plt.ylabel('Number of Students')
plt.show()

# %%
plt.figure()
plt.xlabel('Study Time')
plt.ylabel('Final Grade')
plt.title('Study Time vs Final Grade')
plt.show()

# %%
plt.figure()

corr = data.corr()

plt.imshow(corr)
plt.title('Correlation Matrix')
plt.colorbar()

plt.show()
